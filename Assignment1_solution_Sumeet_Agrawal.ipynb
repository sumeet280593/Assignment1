# %% [markdown]
# **Q1. Why do we call Python as a general purpose and high-level programming language?**

# %% [markdown]
# **Ans)**  Python is a high-level programming language designed to be easy to read and simple to implement. They are not written in machine-readable language, Python programs need to be processed before machines can run them.
#
# Python is an interpreted language. This means that every time a program is run, its interpreter runs through the code and translates it into machine-readable byte code.

# %% [markdown]
# **Q2. Why is Python called a dynamically typed language?**

# %% [markdown]
# **Ans)** In python, there is no need to define the types of variables. It allows to directly use the variables as its type-checking will be done during the execution of the program. The interpreter checks the program line-by-line and also examines the data type of the variable.

# %% [markdown]
# **Q3. List some pros and cons of Python programming language?**

# %% [markdown]
# **Ans) Pros :-**
#
# 1) *Easy to Read, Learn and Write* :- Python is a high-level programming language that has an English-like syntax. This makes it easier to read and understand the code.
#
# 2) *Improved Productivity* :- Python is a very productive language. Due to the simplicity of Python, developers can focus on solving the problem. They don’t need to spend too much time understanding the syntax or behavior of the programming language
#
# 3) *Interpreted Language* :- Python is an interpreted language which means that Python directly executes the code line by line. In case of any error, it stops further execution and reports back the error which has occurred.
#
# 4) *Dynamically Typed* :- Python doesn’t know the type of variable until we run the code. It automatically assigns the data type during execution. The programmer doesn’t need to worry about declaring variables and their data types
#
# 5) *Vast Libraries Support* :- The standard library of Python is huge, you can find almost all the functions needed for your task. So, you don’t have to depend on external libraries.
#
# **Cons :-**
#
# 1)  *Slow Speed* :-  Python is an interpreted language and dynamically-typed language. The line-by-line code execution often leads to slow execution.
#
# 2) *Not Memory Efficient* :- To provide simplicity to the developer, Python has to do a little tradeoff. The Python programming language uses a large amount of memory. This can be a disadvantage while building applications when we prefer memory optimization.
#
# 3) *Runtime Errors* :- Python is a dynamically typed language so the data type of a variable can change anytime. A variable containing an integer number may hold a string in the future, which can lead to Runtime Errors.

# %% [markdown]
# **Q4. In what all domains can we use Python?**

# %% [markdown]
# **Ans)** 1) Machine learning / Artificial intelligence
#
#          2) Desktop GUI
#
#          3) Data analytics and data visualization
#
#          4) Web development
#
#          5) Game development
#
#          6) Mobile app development
#
#          7) Embedded systems

# %% [markdown]
# **Q5. What are variable and how can we declare them?**

# %% [markdown]
# **Ans)** A variable is created when some value is assigned to it. The value assigned to a variable determines the data type of that variable.
#
# To declare a variable in Python:-
#
#     1) Just name the variable
#
#     2) Assign the required value to it
#
#     3) The data type of the variable will be automatically determined from the value assigned, we need not define it explicitly.

# %% [markdown]
# **Q6) How can we take an input from the user in Python?**

# %% [markdown]
# **Ans)** By the help of **input()** function

# %% [markdown]
# **Q7) What is the default datatype of the value that has been taken as an input using input() function?**

# %% [markdown]
# **Ans)** String

# %% [markdown]
# **Q8) What is type casting?**

# %% [markdown]
# **Ans)** Type Casting is the method to convert the variable data type into a certain data type in order to the operation required to be performed by users.

# %% [markdown]
# **Q9. Can we take more than one input from the user using single input() function? If yes, how? If no, why?**

# %% [markdown]
# **Ans)** Yes
#
# Python provides the two methods that help us to take multiple values or input in one line.
#
# 1) Using split() method
#
# 2) Using List Comprehension

# %% [markdown]
# **Q10. What are keywords?**

# %% [markdown]
# **Ans)** Python keywords are special reserved words that have specific meanings and purposes and can't be used for anything but those specific purposes.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Q11. Can we use keywords as a variable? Support your answer with reason.**

# %% [markdown]
# **Ans)** We cannot use a keyword as a variable name, function name, or any other identifier. They are used to define the syntax and structure of the Python language.

# %% [markdown]
# **Q12. What is indentation? What's the use of indentaion in Python?**

# %% [markdown]
# **Ans)** Indentation refers to the spaces at the beginning of a code line. Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important. Python uses indentation to indicate a block of code.

# %% [markdown]
# **Q13. How can we throw some output in Python?**

# %% [markdown]
# **Ans)** By using `print()` function

# %% [markdown]
# **Q14. What are operators in Python?**

# %% [markdown]
# **Ans)** operators are special symbols that designate that some sort of computation should be performed. The values that an operator acts on are called operands.
#
# For example:
# a = 10,
# b = 20
#
# a + b = 30
#
# In this case, the `+` operator adds the operands a and b together.

# %% [markdown]
# **Q15. What is difference between / and // operators?**

# %% [markdown]
# **Ans)**  `/` is the division operator
#
# `//` is the floor division operator.

# %% [markdown]
# **Q16. Write a code that gives following as an output.**
#
# `iNeuroniNeuroniNeuroniNeuron`

# %%
input_var = 'iNeuron'

output_var = input_var*4

output_var
# Out:
# 'iNeuroniNeuroniNeuroniNeuron'

# %% [markdown]
# **Q17. Write a code to take a number as an input from the user and check if the number is odd or even.**

# %%
num = int(input('Enter any number:'))

if num%2 == 0:
    print('{} is even number'.format(num))
else:
    print('{} is odd number'.format(num))
# Out:
# Enter any number:5
# 5 is odd number

# %% [markdown]
# **Q18. What are boolean operator?**

# %% [markdown]
# **Ans)** Boolean Operators are those that result in the Boolean values of True and False. These include and, or and not.

# %% [markdown]
# **Q19. What will the output of the following?**
#
# 1 or 0
#
# 0 and 0
#
# True and False and True
#
# 1 or 0 or 0

# %%
1 or 0
# Out:
# 1

# %%
0 and 0
# Out:
# 0

# %%
True and False and True
# Out:
# False

# %%
1 or 0 or 0
# Out:
# 1

# %% [markdown]
# **Q20. What are conditional statements in Python?**

# %% [markdown]
# **Ans)** Conditional Statement in Python perform different computations or actions depending on whether a specific Boolean constraint evaluates to true or false.

# %% [markdown]
# **Q21. What is use of 'if', 'elif' and 'else' keywords?**

# %% [markdown]
# **Ans)** Python **IF Statement** is used for decision-making operations. It contains a body of code which runs only when the condition given in the if statement is true. If the condition is false, then the optional else statement runs which contains some code for the else condition.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The **“else condition”** is usually used when you have to judge one statement on the basis of other. If one condition goes wrong, then there should be another condition that should justify the statement or logic.

# %% [markdown]
# **Q22.** Write a code to take the age of person as an input and if age >= 18 display "I can vote". If age is < 18 display "I can't vote".

# %%
age = int(input('Enter person age:',))

if age >= 18:
    print("I can vote")
else:
    print("I can't vote")
# Out:
# Enter person age:24
# I can vote

# %% [markdown]
# **Q23.** Write a code that displays the sum of all the even numbers from the given list.

# %%
numbers = [12, 75, 150, 180, 145, 525, 50]

sum_num = 0
for num in numbers:
    if num %2 == 0:
        sum_num += num
        
print(sum_num)
# Out:
# 392

# %% [markdown]
# **Q24. Write a code to take 3 numbers as an input from the user and display the greatest no as output.**

# %%
num_lst = []
for i in range(3):
    x=int(input('Enter interger: '))
    num_lst.append(x)
max_num = max(num_lst)
print('max number is:', max_num)
# Out:
# Enter interger: 41
# Enter interger: 0
# Enter interger: -41
# max number is: 41

# %% [markdown]
# **Q25. Write a program to display only those numbers from a list that satisfy the following conditions**
#
# The number must be divisible by five
#
# If the number is greater than 150, then skip it and move to the next number
#
# If the number is greater than 500, then stop the loop

# %%
lst = [1,-4,0,150,45,165,178,505,10,50,154,45]

out_lst = []

for num in lst:
    if num > 500:
        break
    elif num > 150:
        continue
    elif num%5 == 0:
        out_lst.append(num)

out_lst
# Out:
# [0, 150, 45]
